# %% [markdown]
# # The code to identify the air pollution hotspots using the Three-criteria method explained in Goyal et al., 2021

# %%
import importlib.util
import subprocess


packages = ['numpy', 'pandas', 'tkinter', 'matplotlib', 'xlsxwriter']

for package in packages:
    spec = importlib.util.find_spec(package)
    if spec is None:
        print(f"{package} is not installed. Installing...")
        subprocess.run(['pip', 'install', package])
    else:
        print(f"{package} is already installed.")
# Out:
# numpy is already installed.
# pandas is already installed.
# tkinter is already installed.
# matplotlib is already installed.
# xlsxwriter is already installed.

# %%
# import pandas as pd
import datetime
current_datetime = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
print(current_datetime)
# Out:
# 2024-05-02_18-50-32

# %%
# Read the CSV file into a DataFrame
df = pd.read_csv('./sample_data.csv', parse_dates=["Date"], dayfirst=True)
df = df.replace("NA", pd.NA)

# Threshold value
threshold_value = 67.5  # For PM10
standard_value  = 45.0  # For PM10

# Initialize dictionaries to store places meeting each criterion and the maximum criteria for each month
places_by_month = {}

# Initialize a dictionary to store the places meeting all criteria for each month
places_meeting_all_criteria_by_month = {}

# Initialize a set to store places meeting all criteria across all months
places_meeting_all_criteria = set()

# Create an Excel writer object
writer1 = pd.ExcelWriter(f'{threshold_value}_places_meeting_each_criterion_by_month.xlsx', engine='xlsxwriter')
writer2 = pd.ExcelWriter(f'{threshold_value}_places_meeting_all_criteria_by_month.xlsx', engine='xlsxwriter')
writer3 = pd.ExcelWriter(f'{threshold_value}_places_meeting_all_criteria_hotspots.xlsx', engine='xlsxwriter')
writer4 = pd.ExcelWriter(f'{threshold_value}_criteria1_data.xlsx', engine='xlsxwriter')
writer5 = pd.ExcelWriter(f'{threshold_value}_criteria2_data.xlsx', engine='xlsxwriter')
writer6 = pd.ExcelWriter(f'{threshold_value}_criteria3_data.xlsx', engine='xlsxwriter')

# Iterate over each month
for month, data in df.groupby(df["Date"].dt.to_period("M")):
    month_data = data.copy()
    month_data.reset_index(drop=True, inplace=True)  # Reset index to start from 0
    del month_data["Date"]  # Remove the Date column

    # Initialize sets to store places meeting each criterion for this month
    places_meeting_criterion_1 = set()
    places_meeting_criterion_2 = set()
    places_meeting_criterion_3 = set()

    # Iterate over each place
    for place in month_data.columns:
        ################   Criterion 1  ################
        exceed_threshold_count = (month_data[place] > standard_value).sum()
        month_count = len(month_data)
        month_percentage = (exceed_threshold_count / month_count) * 100
        if month_percentage > 60:
            places_meeting_criterion_1.add((place, month_percentage))

       ################   Criterion 2  ################
        monthly_average = month_data[place].mean()
        exceeding_months = monthly_average > threshold_value
        if exceeding_months:
            places_meeting_criterion_2.add((place, monthly_average))

        ################   Criterion 3  ################
        min_consecutive_days = 3
        exceed_threshold = month_data[place] > threshold_value
        consecutive_exceed_count = 0
        consecutive_days_count = 0

        for value in exceed_threshold:
            if value:  # If the value is True (threshold exceeded)
                consecutive_days_count += 1
                if consecutive_days_count >= min_consecutive_days:
                    consecutive_exceed_count += 1
                    consecutive_days_count = 0  # Reset count after counting a set of consecutive days
            else:  # If the value is False (threshold not exceeded)
                consecutive_days_count = 0  # Reset count if consecutive days are broken

        # Now consecutive_exceed_count represents the number of sets of consecutive days where the threshold is exceeded
        if consecutive_exceed_count > 0:
            places_meeting_criterion_3.add((place, consecutive_exceed_count))


    # Store the places meeting each criterion for this month
    places_by_month[month] = {
        "Criterion 1": places_meeting_criterion_1,
        "Criterion 2": places_meeting_criterion_2,
        "Criterion 3": places_meeting_criterion_3
    }

    ################################################# places_meeting_each_criterion_by_month  #############################################################################################
    # Print places meeting each criterion for this month
    print('#################################################################################################')
    print("Month:", month)
    print('#################################################################################################')
    print("Criterion 1:", places_meeting_criterion_1)
    print("Criterion 2:", places_meeting_criterion_2)
    print("Criterion 3:", places_meeting_criterion_3)
    
    # Create separate DataFrames for each criterion
    sheet_df_criterion1 = pd.DataFrame({"Criterion 1": list(places_meeting_criterion_1)})
    sheet_df_criterion2 = pd.DataFrame({"Criterion 2": list(places_meeting_criterion_2)})
    sheet_df_criterion3 = pd.DataFrame({"Criterion 3": list(places_meeting_criterion_3)})
    # Concatenate DataFrames together
    sheet_df = pd.concat([sheet_df_criterion1, sheet_df_criterion2, sheet_df_criterion3], axis=1)
    # Write the DataFrame to Excel
    sheet_df.to_excel(writer1, sheet_name=f"Month_{month}", index=False)  
    
    
    # Print places meeting each criterion for this month
    print('#################################################################################################')
    print("Month:", month)
    print('#################################################################################################')
    print("| Criterion 1 |:", [place for place, _ in places_meeting_criterion_1])
    print("| Criterion 2 |:", [place for place, _ in places_meeting_criterion_2])
    print("| Criterion 3 |:", [place for place, _ in places_meeting_criterion_3])


    # Find the intersection of places meeting all three criteria for this month
    places_meeting_all_criteria = {place for place, _ in places_meeting_criterion_1} & \
                                   {place for place, _ in places_meeting_criterion_2} & \
                                   {place for place, _ in places_meeting_criterion_3}

    ################################################# places_meeting_all_criteria_by_month  #############################################################################################
    # Print the intersection of places meeting all three criteria for this month
    print('')
    print('------------------------------------------------------------------------------------------------')
    print("Intersection of places meeting all criteria for this month:", places_meeting_all_criteria)
    print('------------------------------------------------------------------------------------------------')
    print('')  # Add an empty line for better readability
    
    # Convert the set to a DataFrame
    df_intersection = pd.DataFrame(list(places_meeting_all_criteria), columns=["Places"])
    # Write the DataFrame to CSV
    df_intersection.to_excel(writer2, sheet_name=f"Month_{month}", index=False)
    
    
    ################################################# places_meeting_all_criteria - HOTSPOTS  #############################################################################################
    # Store the places meeting all criteria for this month in the dictionary
    places_meeting_all_criteria_by_month[month] = places_meeting_all_criteria

# Calculate the intersection of all places meeting all criteria across all months
intersection_of_all_criteria = set.intersection(*places_meeting_all_criteria_by_month.values())

# Print the intersection of all places meeting all criteria across all months
print('')
print('-+++++++++++++++++++++++++++++++++++++++++ HOTSPOTS +++++++++++++++++++++++++++++++++++++++++++++++++++++-')
print("Intersection of all places meeting all criteria across all months:")
print(intersection_of_all_criteria)
print('-++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++-')
print('')
# Convert the set to a DataFrame
df_intersection_all = pd.DataFrame(list(intersection_of_all_criteria), columns=["Places"])
# Write the DataFrame to CSV
df_intersection_all.to_excel(writer3, sheet_name=f"Month_{month}", index=False)

print('')
print('')


###############################################################################################################################################################################
print('')
print('                         Details of places meet each Criterion                                  ')
print('')

# Initialize empty lists to store data
c1_data = []
c2_data = []
c3_data = []

# Print the places meeting each criterion for each month
for month, places in places_by_month.items():
    print('#################################################################################################')
    print(f"Month: {month}")
    print('#################################################################################################')
    for criterion, places_list in places.items():
        # Process Criterion 1
        if criterion == "Criterion 1":
            # Create a string for places meeting Criterion 1
            places_str = ',\n'.join([f"{place[0]} = {place[1]:.2f}%" for place in places_list])
            
            # Find places with maximum percentage
            max_percentage = max(places_list, key=lambda x: x[1])[1]
            max_places = [place[0] for place in places_list if place[1] == max_percentage]
            if len(max_places) > 1:
                # Create a string for places with maximum percentage if multiple places have the same maximum value
                max_places_str = f"Place(s) with maximum percentage:  {', '.join(max_places)} = {max_percentage:.2f}%"
            else:
                # Create a string for single place with maximum percentage
                max_places_str = f"Place with maximum percentage:  {max_places[0]} = {max_percentage:.2f}%"

            # Append data to the list
            c1_data.append([month, places_str, max_places_str])

            # Print statements
            print(f"Month: {month}")
            print("Criterion 1:")
            print('------------------------------------------------------------------------------------------------')
            print(places_str)
            print(max_places_str)
            print(' ')
            
        # Process Criterion 2
        elif criterion == "Criterion 2":
            # Initialize strings for Criterion 2
            places_str = ""
            max_places_str = ""
            # Iterate over places and their monthly averages
            for place, monthly_average in sorted(places_list, key=lambda x: x[0]):
                # Append each place and its average to the string
                places_str += f"{place:<14} = {monthly_average:.2f}\n"
            # Find places with maximum average
            max_average = max(places_list, key=lambda x: x[1])[1]
            max_places2 = [place[0] for place in places_list if place[1] == max_average]
            # Create a string for places with maximum average
            max_places_str = f"Place(s) with maximum average:  {', '.join(max_places2)} = {max_average:.2f}"
            
            # Append data to the list for Criterion 2
            c2_data.append([month, places_str, max_places_str])

            # Print statements for Criterion 2
            print(f"Month: {month}")
            print("Criterion 2:")
            print('------------------------------------------------------------------------------------------------')
            print(places_str)
            print(max_places_str)
            print(' ')
            
        # Process Criterion 2
        elif criterion == "Criterion 3":
            # Initialize strings for Criterion 3
            places_str = ""
            max_places_str = ""
            # Iterate over places and their total exceeding days
            for place, total_exceeding_days in sorted(places_list, key=lambda x: x[0]):
                # Append each place and its total exceeding days to the string
                places_str += f"{place:<15} = {total_exceeding_days}\n"
            # Find the maximum total exceeding days
            max_total_days = max(places_list, key=lambda x: x[1])[1]
            max_places3 = [place[0] for place in places_list if place[1] == max_total_days]
            # Create a string for places with maximum total exceeding days
            max_places_str = f"Place(s) with maximum total exceeding days: {', '.join(max_places3)} = {max_total_days} days"

            # Append data to the list for Criterion 3
            c3_data.append([month, places_str, max_places_str])

            # Print statements for Criterion 3
            print(f"Month: {month}")
            print("Criterion 3:")
            print('------------------------------------------------------------------------------------------------')
            print(places_str)
            print(max_places_str)
            print(' ')
            
###########################################################################################################################################################################

# Criterion 1
criteria1_data = pd.DataFrame(c1_data, columns=["Month", "Places meeting Criterion 1", "Maximum Percentage"])
criteria1_data.to_excel(writer4, sheet_name=f"Criterion_1", index=False)  

# Criterion 2
criteria2_data = pd.DataFrame(c2_data, columns=["Month", "Places meeting Criterion 2", "Maximum Average"])
criteria2_data.to_excel(writer5, sheet_name='Criterion_2', index=False)

# Criterion 3
criteria3_data = pd.DataFrame(c3_data, columns=["Month", "Places meeting Criterion 3", "Maximum Total Exceeding Days"])
criteria3_data.to_excel(writer6, sheet_name='Criterion_3', index=False)

    
# Save the Excel writer object
writer1.save()
writer2.save()
writer3.save()
writer4.save()
writer5.save()
writer6.save()
# Out:
# #################################################################################################
# Month: 2020-12
# #################################################################################################
# Criterion 1: {('Kannur', 100.0), ('Plammood', 74.19354838709677), ('Kozhikkod', 93.54838709677419), ('Karyavattam', 80.64516129032258), ('Kollam', 93.54838709677419), ('Kacheripady', 93.54838709677419), ('Vytilla', 77.41935483870968)}
# Criterion 2: {('Kollam', 92.74689655172415), ('Vytilla', 68.95620689655172), ('Kannur', 84.74806451612902), ('Kacheripady', 74.23709677419355), ('Kozhikkod', 92.74689655172415)}
# Criterion 3: {('Karyavattam', 3), ('Kacheripady', 5), ('Kannur', 6), ('Kozhikkod', 6), ('Plammood', 2), ('Kollam', 6), ('Vytilla', 6)}
# #################################################################################################
# Month: 2020-12
# #################################################################################################
# | Criterion 1 |: ['Kannur', 'Plammood', 'Kozhikkod', 'Karyavattam', 'Kollam', 'Kacheripady', 'Vytilla']
# | Criterion 2 |: ['Kollam', 'Vytilla', 'Kannur', 'Kacheripady', 'Kozhikkod']
# | Criterion 3 |: ['Karyavattam', 'Kacheripady', 'Kannur', 'Kozhikkod', 'Plammood', 'Kollam', 'Vytilla']
#
# ------------------------------------------------------------------------------------------------
# Intersection of places meeting all criteria for this month: {'Kacheripady', 'Kozhikkod', 'Kannur', 'Kollam', 'Vytilla'}
# ------------------------------------------------------------------------------------------------
#
# #################################################################################################
# Month: 2021-01
# #################################################################################################
# Criterion 1: {('Eloor', 83.87096774193549), ('Karyavattam', 74.19354838709677), ('Kannur', 87.09677419354838), ('Kozhikkod', 80.64516129032258), ('Kollam', 80.64516129032258), ('Vytilla', 87.09677419354838), ('Kacheripady', 90.32258064516128)}
# Criterion 2: {('Vytilla', 78.36548387096774), ('Kozhikkod', 80.92800000000001), ('Kollam', 80.92800000000001), ('Kannur', 77.66483870967741), ('Eloor', 90.84451612903227)}
# Criterion 3: {('Plammood', 2), ('Kannur', 7), ('Vytilla', 4), ('Karyavattam', 2), ('Kozhikkod', 5), ('Kacheripady', 3), ('Kollam', 5), ('Eloor', 6)}
# #################################################################################################
# Month: 2021-01
# #################################################################################################
# | Criterion 1 |: ['Eloor', 'Karyavattam', 'Kannur', 'Kozhikkod', 'Kollam', 'Vytilla', 'Kacheripady']
# | Criterion 2 |: ['Vytilla', 'Kozhikkod', 'Kollam', 'Kannur', 'Eloor']
# | Criterion 3 |: ['Plammood', 'Kannur', 'Vytilla', 'Karyavattam', 'Kozhikkod', 'Kacheripady', 'Kollam', 'Eloor']
#
# ------------------------------------------------------------------------------------------------
# Intersection of places meeting all criteria for this month: {'Kozhikkod', 'Eloor', 'Kannur', 'Kollam', 'Vytilla'}
# ------------------------------------------------------------------------------------------------
#
# #################################################################################################
# Month: 2021-02
# #################################################################################################
# Criterion 1: {('Kozhikkod', 100.0), ('Kannur', 82.14285714285714), ('Kollam', 100.0), ('Kacheripady', 96.42857142857143), ('Plammood', 92.85714285714286), ('Vytilla', 100.0), ('Karyavattam', 100.0)}
# Criterion 2: {('Plammood', 72.37178571428572), ('Kacheripady', 85.26037037037037), ('Kannur', 96.14521739130436), ('Vytilla', 95.6907142857143), ('Karyavattam', 89.17285714285713), ('Kozhikkod', 108.68714285714286), ('Kollam', 108.68714285714286)}
# Criterion 3: {('Eloor', 2), ('Vytilla', 8), ('Kozhikkod', 9), ('Plammood', 5), ('Kacheripady', 7), ('Kollam', 9), ('Karyavattam', 8), ('Kannur', 7)}
# #################################################################################################
# Month: 2021-02
# #################################################################################################
# | Criterion 1 |: ['Kozhikkod', 'Kannur', 'Kollam', 'Kacheripady', 'Plammood', 'Vytilla', 'Karyavattam']
# | Criterion 2 |: ['Plammood', 'Kacheripady', 'Kannur', 'Vytilla', 'Karyavattam', 'Kozhikkod', 'Kollam']
# | Criterion 3 |: ['Eloor', 'Vytilla', 'Kozhikkod', 'Plammood', 'Kacheripady', 'Kollam', 'Karyavattam', 'Kannur']
#
# ------------------------------------------------------------------------------------------------
# Intersection of places meeting all criteria for this month: {'Kacheripady', 'Kozhikkod', 'Kannur', 'Karyavattam', 'Kollam', 'Vytilla', 'Plammood'}
# ------------------------------------------------------------------------------------------------
#
# #################################################################################################
# Month: 2021-12
# #################################################################################################
# Criterion 1: {('Kannur', 87.09677419354838), ('Kozhikkod', 93.54838709677419), ('Kollam', 93.54838709677419), ('Kacheripady', 74.19354838709677), ('Eloor', 100.0), ('Karyavattam', 100.0), ('Vytilla', 80.64516129032258)}
# Criterion 2: {('Kacheripady', 68.84580645161292), ('Vytilla', 71.8025806451613), ('Kollam', 125.72758620689655), ('Kozhikkod', 125.72758620689655), ('Eloor', 67.62903225806453), ('Karyavattam', 83.1383870967742), ('Kannur', 73.51419354838711)}
# Criterion 3: {('Plammood', 2), ('Kacheripady', 4), ('Eloor', 5), ('Kozhikkod', 9), ('Karyavattam', 5), ('Vytilla', 4), ('Kollam', 9), ('Kannur', 5)}
# #################################################################################################
# Month: 2021-12
# #################################################################################################
# | Criterion 1 |: ['Kannur', 'Kozhikkod', 'Kollam', 'Kacheripady', 'Eloor', 'Karyavattam', 'Vytilla']
# | Criterion 2 |: ['Kacheripady', 'Vytilla', 'Kollam', 'Kozhikkod', 'Eloor', 'Karyavattam', 'Kannur']
# | Criterion 3 |: ['Plammood', 'Kacheripady', 'Eloor', 'Kozhikkod', 'Karyavattam', 'Vytilla', 'Kollam', 'Kannur']
#
# ------------------------------------------------------------------------------------------------
# Intersection of places meeting all criteria for this month: {'Kacheripady', 'Kozhikkod', 'Eloor', 'Kannur', 'Karyavattam', 'Kollam', 'Vytilla'}
# ------------------------------------------------------------------------------------------------
#
# #################################################################################################
# Month: 2022-01
# #################################################################################################
# Criterion 1: {('Karyavattam', 93.54838709677419), ('Kannur', 90.32258064516128), ('Kozhikkod', 93.54838709677419), ('Kollam', 93.54838709677419), ('Vytilla', 96.7741935483871), ('Eloor', 100.0)}
# Criterion 2: {('Eloor', 69.44645161290323), ('Karyavattam', 83.29709677419355), ('Vytilla', 77.87322580645161), ('Kozhikkod', 86.32310344827586), ('Kannur', 70.06806451612904), ('Kollam', 86.32310344827586)}
# Criterion 3: {('Eloor', 9), ('Kacheripady', 1), ('Karyavattam', 9), ('Kannur', 2), ('Kozhikkod', 8), ('Vytilla', 3), ('Kollam', 8)}
# #################################################################################################
# Month: 2022-01
# #################################################################################################
# | Criterion 1 |: ['Karyavattam', 'Kannur', 'Kozhikkod', 'Kollam', 'Vytilla', 'Eloor']
# | Criterion 2 |: ['Eloor', 'Karyavattam', 'Vytilla', 'Kozhikkod', 'Kannur', 'Kollam']
# | Criterion 3 |: ['Eloor', 'Kacheripady', 'Karyavattam', 'Kannur', 'Kozhikkod', 'Vytilla', 'Kollam']
#
# ------------------------------------------------------------------------------------------------
# Intersection of places meeting all criteria for this month: {'Kozhikkod', 'Eloor', 'Kannur', 'Karyavattam', 'Kollam', 'Vytilla'}
# ------------------------------------------------------------------------------------------------
#
# #################################################################################################
# Month: 2022-02
# #################################################################################################
# Criterion 1: {('Kozhikkod', 96.42857142857143), ('Vytilla', 89.28571428571429), ('Karyavattam', 78.57142857142857), ('Kollam', 96.42857142857143), ('Eloor', 75.0), ('Kannur', 96.42857142857143)}
# Criterion 2: {('Kollam', 94.50481481481482), ('Kozhikkod', 94.50481481481482), ('Vytilla', 77.03392857142856), ('Karyavattam', 83.86260869565216)}
# Criterion 3: {('Kozhikkod', 7), ('Kollam', 7), ('Karyavattam', 5), ('Vytilla', 4), ('Eloor', 4), ('Kannur', 1)}
# #################################################################################################
# Month: 2022-02
# #################################################################################################
# | Criterion 1 |: ['Kozhikkod', 'Vytilla', 'Karyavattam', 'Kollam', 'Eloor', 'Kannur']
# | Criterion 2 |: ['Kollam', 'Kozhikkod', 'Vytilla', 'Karyavattam']
# | Criterion 3 |: ['Kozhikkod', 'Kollam', 'Karyavattam', 'Vytilla', 'Eloor', 'Kannur']
#
# ------------------------------------------------------------------------------------------------
# Intersection of places meeting all criteria for this month: {'Kollam', 'Kozhikkod', 'Vytilla', 'Karyavattam'}
# ------------------------------------------------------------------------------------------------
#
# #################################################################################################
# Month: 2022-12
# #################################################################################################
# Criterion 1: {('Eloor', 74.19354838709677), ('Kannur', 100.0), ('Plammood', 64.51612903225806), ('Kozhikkod', 96.7741935483871), ('Karyavattam', 80.64516129032258), ('Kollam', 96.7741935483871), ('Vytilla', 93.54838709677419)}
# Criterion 2: {('Kozhikkod', 93.76354838709678), ('Kollam', 93.76354838709678), ('Vytilla', 99.88633333333337)}
# Criterion 3: {('Kozhikkod', 7), ('Karyavattam', 3), ('Kollam', 7), ('Eloor', 2), ('Kannur', 3), ('Plammood', 1), ('Vytilla', 6)}
# #################################################################################################
# Month: 2022-12
# #################################################################################################
# | Criterion 1 |: ['Eloor', 'Kannur', 'Plammood', 'Kozhikkod', 'Karyavattam', 'Kollam', 'Vytilla']
# | Criterion 2 |: ['Kozhikkod', 'Kollam', 'Vytilla']
# | Criterion 3 |: ['Kozhikkod', 'Karyavattam', 'Kollam', 'Eloor', 'Kannur', 'Plammood', 'Vytilla']
#
# ------------------------------------------------------------------------------------------------
# Intersection of places meeting all criteria for this month: {'Kollam', 'Kozhikkod', 'Vytilla'}
# ------------------------------------------------------------------------------------------------
#
# #################################################################################################
# Month: 2023-01
# #################################################################################################
# Criterion 1: {('Plammood', 93.54838709677419), ('Eloor', 67.74193548387096), ('Kozhikkod', 100.0), ('Kannur', 93.54838709677419), ('Karyavattam', 93.54838709677419), ('Kollam', 100.0), ('Vytilla', 100.0)}
# Criterion 2: {('Kollam', 103.39648926906781), ('Kannur', 72.89352829911802), ('Kozhikkod', 103.39648926906781), ('Vytilla', 92.92549159038893), ('Karyavattam', 76.98231017015385), ('Plammood', 73.2980830773169), ('Eloor', 76.07796395502642)}
# Criterion 3: {('Kozhikkod', 9), ('Plammood', 5), ('Kollam', 9), ('Eloor', 4), ('Vytilla', 10), ('Kannur', 7), ('Karyavattam', 7)}
# #################################################################################################
# Month: 2023-01
# #################################################################################################
# | Criterion 1 |: ['Plammood', 'Eloor', 'Kozhikkod', 'Kannur', 'Karyavattam', 'Kollam', 'Vytilla']
# | Criterion 2 |: ['Kollam', 'Kannur', 'Kozhikkod', 'Vytilla', 'Karyavattam', 'Plammood', 'Eloor']
# | Criterion 3 |: ['Kozhikkod', 'Plammood', 'Kollam', 'Eloor', 'Vytilla', 'Kannur', 'Karyavattam']
#
# ------------------------------------------------------------------------------------------------
# Intersection of places meeting all criteria for this month: {'Kozhikkod', 'Eloor', 'Kannur', 'Karyavattam', 'Kollam', 'Vytilla', 'Plammood'}
# ------------------------------------------------------------------------------------------------
#
# #################################################################################################
# Month: 2023-02
# #################################################################################################
# Criterion 1: {('Kozhikkod', 100.0), ('Plammood', 89.28571428571429), ('Kollam', 100.0), ('Eloor', 71.42857142857143), ('Kannur', 89.28571428571429), ('Karyavattam', 96.42857142857143), ('Vytilla', 78.57142857142857)}
# Criterion 2: {('Kozhikkod', 89.84352886988934), ('Vytilla', 101.92816498413404), ('Plammood', 68.87263306590744), ('Eloor', 77.32800441625096), ('Karyavattam', 76.03300272509361), ('Kollam', 89.84352886988934)}
# Criterion 3: {('Kozhikkod', 7), ('Kollam', 7), ('Karyavattam', 6), ('Eloor', 5), ('Kannur', 2), ('Vytilla', 6), ('Plammood', 3)}
# #################################################################################################
# Month: 2023-02
# #################################################################################################
# | Criterion 1 |: ['Kozhikkod', 'Plammood', 'Kollam', 'Eloor', 'Kannur', 'Karyavattam', 'Vytilla']
# | Criterion 2 |: ['Kozhikkod', 'Vytilla', 'Plammood', 'Eloor', 'Karyavattam', 'Kollam']
# | Criterion 3 |: ['Kozhikkod', 'Kollam', 'Karyavattam', 'Eloor', 'Kannur', 'Vytilla', 'Plammood']
#
# ------------------------------------------------------------------------------------------------
# Intersection of places meeting all criteria for this month: {'Kozhikkod', 'Eloor', 'Karyavattam', 'Kollam', 'Vytilla', 'Plammood'}
# ------------------------------------------------------------------------------------------------
#
#
# -+++++++++++++++++++++++++++++++++++++++++ HOTSPOTS +++++++++++++++++++++++++++++++++++++++++++++++++++++-
# Intersection of all places meeting all criteria across all months:
# {'Kollam', 'Kozhikkod', 'Vytilla'}
# -++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++-
#
#
#
#
#                          Details of places meet each Criterion
#
# #################################################################################################
# Month: 2020-12
# #################################################################################################
# Month: 2020-12
# Criterion 1:
# ------------------------------------------------------------------------------------------------
# Kannur = 100.00%,
# Plammood = 74.19%,
# Kozhikkod = 93.55%,
# Karyavattam = 80.65%,
# Kollam = 93.55%,
# Kacheripady = 93.55%,
# Vytilla = 77.42%
# Place with maximum percentage:  Kannur = 100.00%
#
# Month: 2020-12
# Criterion 2:
# ------------------------------------------------------------------------------------------------
# Kacheripady    = 74.24
# Kannur         = 84.75
# Kollam         = 92.75
# Kozhikkod      = 92.75
# Vytilla        = 68.96
#
# Place(s) with maximum average:  Kollam, Kozhikkod = 92.75
#
# Month: 2020-12
# Criterion 3:
# ------------------------------------------------------------------------------------------------
# Kacheripady     = 5
# Kannur          = 6
# Karyavattam     = 3
# Kollam          = 6
# Kozhikkod       = 6
# Plammood        = 2
# Vytilla         = 6
#
# Place(s) with maximum total exceeding days: Kannur, Kozhikkod, Kollam, Vytilla = 6 days
#
# #################################################################################################
# Month: 2021-01
# #################################################################################################
# Month: 2021-01
# Criterion 1:
# ------------------------------------------------------------------------------------------------
# Eloor = 83.87%,
# Karyavattam = 74.19%,
# Kannur = 87.10%,
# Kozhikkod = 80.65%,
# Kollam = 80.65%,
# Vytilla = 87.10%,
# Kacheripady = 90.32%
# Place with maximum percentage:  Kacheripady = 90.32%
#
# Month: 2021-01
# Criterion 2:
# ------------------------------------------------------------------------------------------------
# Eloor          = 90.84
# Kannur         = 77.66
# Kollam         = 80.93
# Kozhikkod      = 80.93
# Vytilla        = 78.37
#
# Place(s) with maximum average:  Eloor = 90.84
#
# Month: 2021-01
# Criterion 3:
# ------------------------------------------------------------------------------------------------
# Eloor           = 6
# Kacheripady     = 3
# Kannur          = 7
# Karyavattam     = 2
# Kollam          = 5
# Kozhikkod       = 5
# Plammood        = 2
# Vytilla         = 4
#
# Place(s) with maximum total exceeding days: Kannur = 7 days
#
# #################################################################################################
# Month: 2021-02
# #################################################################################################
# Month: 2021-02
# Criterion 1:
# ------------------------------------------------------------------------------------------------
# Kozhikkod = 100.00%,
# Kannur = 82.14%,
# Kollam = 100.00%,
# Kacheripady = 96.43%,
# Plammood = 92.86%,
# Vytilla = 100.00%,
# Karyavattam = 100.00%
# Place(s) with maximum percentage:  Kozhikkod, Kollam, Vytilla, Karyavattam = 100.00%
#
# Month: 2021-02
# Criterion 2:
# ------------------------------------------------------------------------------------------------
# Kacheripady    = 85.26
# Kannur         = 96.15
# Karyavattam    = 89.17
# Kollam         = 108.69
# Kozhikkod      = 108.69
# Plammood       = 72.37
# Vytilla        = 95.69
#
# Place(s) with maximum average:  Kozhikkod, Kollam = 108.69
#
# Month: 2021-02
# Criterion 3:
# ------------------------------------------------------------------------------------------------
# Eloor           = 2
# Kacheripady     = 7
# Kannur          = 7
# Karyavattam     = 8
# Kollam          = 9
# Kozhikkod       = 9
# Plammood        = 5
# Vytilla         = 8
#
# Place(s) with maximum total exceeding days: Kozhikkod, Kollam = 9 days
#
# #################################################################################################
# Month: 2021-12
# #################################################################################################
# Month: 2021-12
# Criterion 1:
# ------------------------------------------------------------------------------------------------
# Kannur = 87.10%,
# Kozhikkod = 93.55%,
# Kollam = 93.55%,
# Kacheripady = 74.19%,
# Eloor = 100.00%,
# Karyavattam = 100.00%,
# Vytilla = 80.65%
# Place(s) with maximum percentage:  Eloor, Karyavattam = 100.00%
#
# Month: 2021-12
# Criterion 2:
# ------------------------------------------------------------------------------------------------
# Eloor          = 67.63
# Kacheripady    = 68.85
# Kannur         = 73.51
# Karyavattam    = 83.14
# Kollam         = 125.73
# Kozhikkod      = 125.73
# Vytilla        = 71.80
#
# Place(s) with maximum average:  Kollam, Kozhikkod = 125.73
#
# Month: 2021-12
# Criterion 3:
# ------------------------------------------------------------------------------------------------
# Eloor           = 5
# Kacheripady     = 4
# Kannur          = 5
# Karyavattam     = 5
# Kollam          = 9
# Kozhikkod       = 9
# Plammood        = 2
# Vytilla         = 4
#
# Place(s) with maximum total exceeding days: Kozhikkod, Kollam = 9 days
#
# #################################################################################################
# Month: 2022-01
# #################################################################################################
# Month: 2022-01
# Criterion 1:
# ------------------------------------------------------------------------------------------------
# Karyavattam = 93.55%,
# Kannur = 90.32%,
# Kozhikkod = 93.55%,
# Kollam = 93.55%,
# Vytilla = 96.77%,
# Eloor = 100.00%
# Place with maximum percentage:  Eloor = 100.00%
#
# Month: 2022-01
# Criterion 2:
# ------------------------------------------------------------------------------------------------
# Eloor          = 69.45
# Kannur         = 70.07
# Karyavattam    = 83.30
# Kollam         = 86.32
# Kozhikkod      = 86.32
# Vytilla        = 77.87
#
# Place(s) with maximum average:  Kozhikkod, Kollam = 86.32
#
# Month: 2022-01
# Criterion 3:
# ------------------------------------------------------------------------------------------------
# Eloor           = 9
# Kacheripady     = 1
# Kannur          = 2
# Karyavattam     = 9
# Kollam          = 8
# Kozhikkod       = 8
# Vytilla         = 3
#
# Place(s) with maximum total exceeding days: Eloor, Karyavattam = 9 days
#
# #################################################################################################
# Month: 2022-02
# #################################################################################################
# Month: 2022-02
# Criterion 1:
# ------------------------------------------------------------------------------------------------
# Kozhikkod = 96.43%,
# Vytilla = 89.29%,
# Karyavattam = 78.57%,
# Kollam = 96.43%,
# Eloor = 75.00%,
# Kannur = 96.43%
# Place(s) with maximum percentage:  Kozhikkod, Kollam, Kannur = 96.43%
#
# Month: 2022-02
# Criterion 2:
# ------------------------------------------------------------------------------------------------
# Karyavattam    = 83.86
# Kollam         = 94.50
# Kozhikkod      = 94.50
# Vytilla        = 77.03
#
# Place(s) with maximum average:  Kollam, Kozhikkod = 94.50
#
# Month: 2022-02
# Criterion 3:
# ------------------------------------------------------------------------------------------------
# Eloor           = 4
# Kannur          = 1
# Karyavattam     = 5
# Kollam          = 7
# Kozhikkod       = 7
# Vytilla         = 4
#
# Place(s) with maximum total exceeding days: Kozhikkod, Kollam = 7 days
#
# #################################################################################################
# Month: 2022-12
# #################################################################################################
# Month: 2022-12
# Criterion 1:
# ------------------------------------------------------------------------------------------------
# Eloor = 74.19%,
# Kannur = 100.00%,
# Plammood = 64.52%,
# Kozhikkod = 96.77%,
# Karyavattam = 80.65%,
# Kollam = 96.77%,
# Vytilla = 93.55%
# Place with maximum percentage:  Kannur = 100.00%
#
# Month: 2022-12
# Criterion 2:
# ------------------------------------------------------------------------------------------------
# Kollam         = 93.76
# Kozhikkod      = 93.76
# Vytilla        = 99.89
#
# Place(s) with maximum average:  Vytilla = 99.89
#
# Month: 2022-12
# Criterion 3:
# ------------------------------------------------------------------------------------------------
# Eloor           = 2
# Kannur          = 3
# Karyavattam     = 3
# Kollam          = 7
# Kozhikkod       = 7
# Plammood        = 1
# Vytilla         = 6
#
# Place(s) with maximum total exceeding days: Kozhikkod, Kollam = 7 days
#
# #################################################################################################
# Month: 2023-01
# #################################################################################################
# Month: 2023-01
# Criterion 1:
# ------------------------------------------------------------------------------------------------
# Plammood = 93.55%,
# Eloor = 67.74%,
# Kozhikkod = 100.00%,
# Kannur = 93.55%,
# Karyavattam = 93.55%,
# Kollam = 100.00%,
# Vytilla = 100.00%
# Place(s) with maximum percentage:  Kozhikkod, Kollam, Vytilla = 100.00%
#
# Month: 2023-01
# Criterion 2:
# ------------------------------------------------------------------------------------------------
# Eloor          = 76.08
# Kannur         = 72.89
# Karyavattam    = 76.98
# Kollam         = 103.40
# Kozhikkod      = 103.40
# Plammood       = 73.30
# Vytilla        = 92.93
#
# Place(s) with maximum average:  Kollam, Kozhikkod = 103.40
#
# Month: 2023-01
# Criterion 3:
# ------------------------------------------------------------------------------------------------
# Eloor           = 4
# Kannur          = 7
# Karyavattam     = 7
# Kollam          = 9
# Kozhikkod       = 9
# Plammood        = 5
# Vytilla         = 10
#
# Place(s) with maximum total exceeding days: Vytilla = 10 days
#
# #################################################################################################
# Month: 2023-02
# #################################################################################################
# Month: 2023-02
# Criterion 1:
# ------------------------------------------------------------------------------------------------
# Kozhikkod = 100.00%,
# Plammood = 89.29%,
# Kollam = 100.00%,
# Eloor = 71.43%,
# Kannur = 89.29%,
# Karyavattam = 96.43%,
# Vytilla = 78.57%
# Place(s) with maximum percentage:  Kozhikkod, Kollam = 100.00%
#
# Month: 2023-02
# Criterion 2:
# ------------------------------------------------------------------------------------------------
# Eloor          = 77.33
# Karyavattam    = 76.03
# Kollam         = 89.84
# Kozhikkod      = 89.84
# Plammood       = 68.87
# Vytilla        = 101.93
#
# Place(s) with maximum average:  Vytilla = 101.93
#
# Month: 2023-02
# Criterion 3:
# ------------------------------------------------------------------------------------------------
# Eloor           = 5
# Kannur          = 2
# Karyavattam     = 6
# Kollam          = 7
# Kozhikkod       = 7
# Plammood        = 3
# Vytilla         = 6
#
# Place(s) with maximum total exceeding days: Kozhikkod, Kollam = 7 days
# /tmp/ipykernel_24625/2829190810.py:262: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer1.save()
# /tmp/ipykernel_24625/2829190810.py:263: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer2.save()
# /tmp/ipykernel_24625/2829190810.py:264: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer3.save()
# /tmp/ipykernel_24625/2829190810.py:265: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer4.save()
# /tmp/ipykernel_24625/2829190810.py:266: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer5.save()
# /tmp/ipykernel_24625/2829190810.py:267: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer6.save()

# %% [markdown]
# # END OF  CODE
